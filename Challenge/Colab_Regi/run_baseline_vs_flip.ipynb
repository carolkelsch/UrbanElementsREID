# %% [markdown]
# # INIT

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Part-Aware-Transformer
# Out:
# /content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Part-Aware-Transformer

# %%
# !pip install yacs

# %%
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.2/819.2 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 119.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 101.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 102.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 55.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 126.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 36.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 17.0 MB/s eta 0:00:00
# ...

# %%
# !pip install numpy==1.26.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 106.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# %ls
# Out:
# config/         model/             run.sh    update_flip.py  visualization/
# data/           predict_kaggle.py  solver/   update_GPS.py
# enviroments.sh  processor/         test.py   update.py
# loss/           README.md          train.py  utils/

# %%
# !python -m wget https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-vitjx/jx_vit_base_p16_224-80ecf9dd.pth -o ../jx_vit_base_p16_224-80ecf9dd.pth
# Out:
# /usr/bin/python3: No module named wget

# %% [markdown]
# # T

# %%
# !python ../Part-Aware-Transformer/train.py --config_file "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Colab_Regi/UAM_kaggle.yml"
# Out:
# 2025-05-25 11:14:06.137024: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-25 11:14:06.156110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748171646.177826    2723 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748171646.184595    2723 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Kaggle predict without flip

# %%
# !python ../Part-Aware-Transformer/update.py --config_file "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Colab_Regi/UAM_kaggle_test.yml" --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_kaggle_no_flip_merged.txt"
# Out:
# 2025-05-25 19:04:32.376943: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-25 19:04:32.397958: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748199872.420878   11495 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748199872.427602   11495 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cat "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_kaggle_no_flip_merged.txt"

# %%
# !python ../Part-Aware-Transformer/update_flip.py --config_file "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Colab_Regi/UAM_kaggle_test.yml" --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track.txt"
# Out:
# 2025-05-25 12:07:54.447768: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-25 12:07:54.467569: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748174874.489885   30936 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748174874.496585   30936 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Unified Flip results (trained on merged datasetÖ

# %%
# !python ../Part-Aware-Transformer/update_flip.py --config_file "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Colab_Regi/UAM_unified_test.yml"   --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_unfied.txt"
# Out:
# 2025-05-25 12:50:37.628654: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-25 12:50:37.647972: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748177437.669322    5465 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748177437.675895    5465 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py   --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_unfied.txt" --path="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3/UrbAM-ReID/Data/unified/"
# Out:
# mAP= 0.41181135391203
# CMC-1 =0.31155778894472
# CMC-5 =0.53266331658291
# CMC-10 =0.77386934673367
# CMC-15 =0.81909547738693
# CMC-20 =0.85427135678392
# CMC-30 =0.89949748743719
# CMC-45 =0.93969849246231
# CMC-100 =0.99497487437186

# %% [markdown]
# ## Unified set Results without flip (trained on merged dataset)

# %%
# !python ../Part-Aware-Transformer/update.py --config_file "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Colab_Regi/UAM_unified_test.yml"   --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_unfied_without_flip.txt"
# Out:
# 2025-05-25 18:31:02.242473: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-25 18:31:02.263432: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748197862.286590    2596 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748197862.293471    2596 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py   --track="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3_latest/Challenge/Results/track_unfied_without_flip.txt" --path="/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/PRC3/UrbAM-ReID/Data/unified/"
# Out:
# mAP= 0.41378026055667
# CMC-1 =0.30653266331658
# CMC-5 =0.54271356783920
# CMC-10 =0.74874371859296
# CMC-15 =0.80904522613065
# CMC-20 =0.84422110552764
# CMC-30 =0.87437185929648
# CMC-45 =0.93969849246231
# CMC-100 =0.99497487437186
