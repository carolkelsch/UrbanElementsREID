# %% [markdown]
# ## Create a conda environment and activate it

# %%
# !bash ../../Part-Aware-Transformer/enviroments.sh
# Out:
# Collecting torch
#   Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.22.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch) (4.13.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from triton==3.3.0->torch) (78.1.1)
# Collecting numpy (from torchvision)
#   Downloading numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 44.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 51.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 59.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 57.1 MB/s eta 0:00:00:00:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 39.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 45.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 62.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 58.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 63.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 62.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 62.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 62.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 54.9 MB/s eta 0:00:00:00:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 MB 63.6 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.22.0-cp310-cp310-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 58.6 MB/s eta 0:00:00
# Downloading torchaudio-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.5 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 57.8 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 56.6 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 32.1 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 48.9 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 60.3 MB/s eta 0:00:00:00:01
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [torchaudio]7 [torchaudio]]ver-cu12]2]2]
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.5 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 pillow-11.2.1 sympy-1.14.0 torch-2.7.0 torchaudio-2.7.0 torchvision-0.22.0 triton-3.3.0
# Collecting einops
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Installing collected packages: einops
# Successfully installed einops-0.8.1
# Collecting timm
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: torch in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from timm) (2.7.0)
# Requirement already satisfied: torchvision in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from timm) (0.22.0)
# Collecting pyyaml (from timm)
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface_hub (from timm)
#   Downloading huggingface_hub-0.31.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors (from timm)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from huggingface_hub->timm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from huggingface_hub->timm) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from huggingface_hub->timm) (25.0)
# Collecting requests (from huggingface_hub->timm)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.42.1 (from huggingface_hub->timm)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from huggingface_hub->timm) (4.13.2)
# Collecting hf-xet<2.0.0,>=1.1.0 (from huggingface_hub->timm)
#   Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface_hub->timm)
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface_hub->timm)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface_hub->timm)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface_hub->timm)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: sympy>=1.13.3 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch->timm) (3.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from triton==3.3.0->torch->timm) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: numpy in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torchvision->timm) (2.2.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torchvision->timm) (11.2.1)
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.31.1-py3-none-any.whl (484 kB)
# Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 59.9 MB/s eta 0:00:00:00:0100:01
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 40.2 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Installing collected packages: urllib3, tqdm, safetensors, pyyaml, idna, hf-xet, charset-normalizer, certifi, requests, huggingface_hub, timm
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [timm]2m10/11 [timm]ngface_hub]
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 hf-xet-1.1.0 huggingface_hub-0.31.1 idna-3.10 pyyaml-6.0.2 requests-2.32.3 safetensors-0.5.3 timm-1.0.15 tqdm-4.67.1 urllib3-2.4.0
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.24 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from scikit-image) (2.2.5)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: networkx>=3.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from scikit-image) (11.2.1)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from scikit-image) (25.0)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 53.1 MB/s eta 0:00:00:00:01
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 62.0 MB/s eta 0:00:00:00:0100:01
# Downloading tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Installing collected packages: tifffile, scipy, lazy-loader, imageio, scikit-image
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [scikit-image] [scikit-image]
# Successfully installed imageio-2.37.0 lazy-loader-0.4 scikit-image-0.25.2 scipy-1.15.3 tifffile-2025.3.30
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from opencv-python) (2.2.5)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 56.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.71.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from tensorboard) (2.2.5)
# Requirement already satisfied: packaging in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from tensorboard) (25.0)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard)
#   Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from tensorboard) (78.1.1)
# Requirement already satisfied: six>1.9 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from tensorboard) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 50.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 52.0 MB/s eta 0:00:00
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading grpcio-1.71.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 58.6 MB/s eta 0:00:00
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading protobuf-6.30.2-cp39-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, absl-py, tensorboard
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [tensorboard] [tensorboard]data-server]
# Successfully installed absl-py-2.2.2 grpcio-1.71.0 markdown-3.8 protobuf-6.30.2 tensorboard-2.19.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from yacs) (6.0.2)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8

# %%
# !conda env update --file ../../UrbAM-ReID/environmentPAT.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages:
# python-3.10.0        | 23.5 MB   |                                       |   0%
# numpy-base-1.26.4    | 7.2 MB    |                                       |   0%
#
# libopenblas-0.3.21   | 5.4 MB    |                                       |   0%
#
#
# openssl-1.1.1w       | 3.7 MB    |                                       |   0%
#
#
#
# tk-8.6.12            | 3.0 MB    |                                       |   0%
#
#
#
#
# sqlite-3.41.2        | 1.2 MB    |                                       |   0%
#
#
#
#
#
# xz-5.4.6             | 651 KB    |                                       |   0%
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    |                                       |   0%
#
#
#
#
#
#
#
# zlib-1.2.13          | 103 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libffi-3.3           | 50 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# blas-1.0             | 46 KB     |                                       |   0%
#
# python-3.10.0        | 23.5 MB   | 1                                     |   0%
# numpy-base-1.26.4    | 7.2 MB    | 3                                     |   1%
#
#
#
# tk-8.6.12            | 3.0 MB    | 7                                     |   2%
#
#
# python-3.10.0        | 23.5 MB   | ##6                                   |   7%
#
# libopenblas-0.3.21   | 5.4 MB    | ######2                               |  17%
#
#
# openssl-1.1.1w       | 3.7 MB    | ###############3                      |  41%
# numpy-base-1.26.4    | 7.2 MB    | ###7                                  |  10%
#
#
#
# python-3.10.0        | 23.5 MB   | #####2                                |  14%
#
# libopenblas-0.3.21   | 5.4 MB    | ##############################3       |  82%
# numpy-base-1.26.4    | 7.2 MB    | #####################7                |  59%
#
#
#
# tk-8.6.12            | 3.0 MB    | ##################################7   |  94%
#
#
#
#
# sqlite-3.41.2        | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
# xz-5.4.6             | 651 KB    | 9                                     |   2%
#
#
# openssl-1.1.1w       | 3.7 MB    | ##################################### | 100%
#
#
# python-3.10.0        | 23.5 MB   | ##########5                           |  29%
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
# zlib-1.2.13          | 103 KB    | #####7                                |  15%
#
#
#
#
#
#
#
#
# libffi-3.3           | 50 KB     | ###########7                          |  32%
#
#
#
#
# sqlite-3.41.2        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 23.5 MB   | ##############4                       |  39%
#
#
#
#
#
# xz-5.4.6             | 651 KB    | ##################################### | 100%
#
#
#
#
#
# xz-5.4.6             | 651 KB    | ##################################### | 100%
#
# libopenblas-0.3.21   | 5.4 MB    | ##################################### | 100%
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | ##################################### | 100%
#
#
#
# tk-8.6.12            | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# zlib-1.2.13          | 103 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# zlib-1.2.13          | 103 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libffi-3.3           | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# libffi-3.3           | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# blas-1.0             | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 23.5 MB   | ##########################2           |  71%
# numpy-base-1.26.4    | 7.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/home/alumnos/e536103/.conda/envs/conda_PatREID/bin/python', '-m', 'pip', 'install', '-U', '-r', '/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting absl-py==2.1.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 1))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting certifi==2024.2.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 2))
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 3))
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting einops==0.7.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 4))
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock==3.13.3 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 5))
#   Downloading filelock-3.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec==2024.3.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 6))
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting grpcio==1.62.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 7))
#   Downloading grpcio-1.62.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting huggingface-hub==0.22.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 8))
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Collecting idna==3.6 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 9))
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting imageio==2.34.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 10))
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting jinja2==3.1.3 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 11))
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting lazy-loader==0.4 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 12))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting markdown==3.6 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 13))
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting markupsafe==2.1.5 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 14))
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting mpmath==1.3.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 15))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting networkx==3.3 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 16))
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy==1.26.4 in /home/alumnos/e536103/.conda/envs/conda_PatREID/lib/python3.10/site-packages (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 17)) (1.26.4)
# Collecting nvidia-cublas-cu11==11.11.3.6 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 18))
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 19))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 20))
#   Downloading nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 21))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 22))
#   Downloading nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 23))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 24))
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 25))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu11==8.7.0.84 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 26))
#   Downloading nvidia_cudnn_cu11-8.7.0.84-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 27))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 28))
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 29))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.3.0.86 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 30))
#   Downloading nvidia_curand_cu11-10.3.0.86-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 31))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 32))
#   Downloading nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 33))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 34))
#   Downloading nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 35))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.19.3 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 36))
#   Downloading nvidia_nccl_cu11-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 37))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 38))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu11==11.8.86 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 39))
#   Downloading nvidia_nvtx_cu11-11.8.86-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 40))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting opencv-python==4.9.0.80 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 41))
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting packaging==24.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 42))
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow==10.3.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 43))
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pip==23.3.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 44))
#   Downloading pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting protobuf==5.26.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 45))
#   Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pyyaml==6.0.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 46))
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests==2.31.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 47))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting safetensors==0.4.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 48))
#   Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting scikit-image==0.22.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 49))
#   Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting scipy==1.13.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 50))
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting setuptools==68.2.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 51))
#   Downloading setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting six==1.16.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 52))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting sympy==1.12 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 53))
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting tensorboard==2.16.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 54))
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboard-data-server==0.7.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 55))
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting tifffile==2024.2.12 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 56))
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Collecting timm==0.9.16 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 57))
#   Downloading timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Collecting torch==2.2.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 58))
#   Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchaudio==2.2.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 59))
#   Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.17.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 60))
#   Downloading torchvision-0.17.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm==4.66.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 61))
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Collecting triton==2.2.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 62))
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting typing-extensions==4.11.0 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 63))
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting urllib3==2.2.1 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 64))
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting werkzeug==3.0.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 65))
#   Downloading werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting wheel==0.41.2 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 66))
#   Downloading wheel-0.41.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting yacs==0.1.8 (from -r /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/UrbAM-ReID/condaenv.2mrn9vbl.requirements.txt (line 67))
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
# Downloading filelock-3.13.3-py3-none-any.whl (11 kB)
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Downloading grpcio-1.62.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 56.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
# Downloading idna-3.6-py3-none-any.whl (61 kB)
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 49.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 50.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 50.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 53.2 MB/s eta 0:00:00:00:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 55.0 MB/s eta 0:00:00:00:01
# Downloading nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 54.7 MB/s eta 0:00:00:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━�━━━━━━━╸ 23.6/23.7 MB 120.4 MB/s eta 0:00:01�━━━━━━━━ 23.7/23.7 MB 62.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 37.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.7.0.84-py3-none-manylinux1_x86_64.whl (728.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 47.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 49.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 59.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 61.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu11-10.3.0.86-py3-none-manylinux2014_x86_64.whl (58.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 52.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 60.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux2014_x86_64.whl (128.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 61.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 62.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux2014_x86_64.whl (204.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 79.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 62.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu11-2.19.3-py3-none-manylinux1_x86_64.whl (135.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 59.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 62.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.3 MB/s eta 0:00:00:00:01
# Downloading nvidia_nvtx_cu11-11.8.86-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 60.9 MB/s eta 0:00:00:00:0100:01
# Downloading packaging-24.0-py3-none-any.whl (53 kB)
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 56.1 MB/s eta 0:00:00
# Downloading pip-23.3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 61.4 MB/s eta 0:00:00
# Downloading protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 41.4 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
# Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.7 MB/s eta 0:00:00
# Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 54.6 MB/s eta 0:00:00:00:01
# Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Downloading setuptools-68.2.2-py3-none-any.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 24.6 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 41.6 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 42.3 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
# Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.4 MB/s eta 0:00:00
# Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 42.6 MB/s eta 0:00:0000:0100:01
# Downloading torchaudio-2.2.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 54.6 MB/s eta 0:00:00
# Downloading torchvision-0.17.1-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.9 MB/s eta 0:00:00
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 63.2 MB/s eta 0:00:0000:0100:01
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
# Downloading wheel-0.41.2-py3-none-any.whl (64 kB)
# Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: mpmath, wheel, urllib3, typing-extensions, tqdm, tifffile, tensorboard-data-server, sympy, six, setuptools, scipy, safetensors, pyyaml, protobuf, pip, pillow, packaging, opencv-python, nvidia-nvtx-cu12, nvidia-nvtx-cu11, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu12, nvidia-curand-cu11, nvidia-cufft-cu12, nvidia-cufft-cu11, nvidia-cuda-runtime-cu12, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu12, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu12, nvidia-cuda-cupti-cu11, nvidia-cublas-cu12, nvidia-cublas-cu11, networkx, markupsafe, markdown, idna, grpcio, fsspec, filelock, einops, charset-normalizer, certifi, absl-py, yacs, werkzeug, triton, requests, nvidia-cusparse-cu12, nvidia-cusolver-cu11, nvidia-cudnn-cu12, nvidia-cudnn-cu11, lazy-loader, jinja2, imageio, tensorboard, scikit-image, nvidia-cusolver-cu12, huggingface-hub, torch, torchvision, torchaudio, timm
#   Attempting uninstall: wheel━━━━━━━━━━━━━━━━━━━  0/66 [mpmath]
#     Found existing installation: wheel 0.45.1  0/66 [mpmath]
#     Uninstalling wheel-0.45.1:━━━━━━━━━━━━━━  0/66 [mpmath]
#       Successfully uninstalled wheel-0.45.1━  0/66 [mpmath]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/66 [sympy]board-data-server]
#     Found existing installation: setuptools 78.1.1━━━━━━━━━━━━  7/66 [sympy]
#     Uninstalling setuptools-78.1.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/66 [sympy]
#       Successfully uninstalled setuptools-78.1.1━━━━━━━━━━━━━━  7/66 [sympy]
#   Attempting uninstall: pip0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/66 [pyyaml]ols]
#     Found existing installation: pip 25.1━━━━━━━━━━━━━━━━━━━━━ 12/66 [pyyaml]
#     Uninstalling pip-25.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/66 [pyyaml]
#       Successfully uninstalled pip-25.1━━━━━━━━━━━━━━━━━━━━━━━ 12/66 [pyyaml]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66/66 [timm]0m [timm]0m [torchaudio]]hub]cu12]1]1]
# Successfully installed absl-py-2.1.0 certifi-2024.2.2 charset-normalizer-3.3.2 einops-0.7.0 filelock-3.13.3 fsspec-2024.3.1 grpcio-1.62.1 huggingface-hub-0.22.2 idna-3.6 imageio-2.34.0 jinja2-3.1.3 lazy-loader-0.4 markdown-3.6 markupsafe-2.1.5 mpmath-1.3.0 networkx-3.3 nvidia-cublas-cu11-11.11.3.6 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu11-8.7.0.84 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu11-10.9.0.58 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu11-10.3.0.86 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu11-11.7.5.86 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu11-2.19.3 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu11-11.8.86 nvidia-nvtx-cu12-12.1.105 opencv-python-4.9.0.80 packaging-24.0 pillow-10.3.0 pip-23.3.1 protobuf-5.26.1 pyyaml-6.0.1 requests-2.31.0 safetensors-0.4.2 scikit-image-0.22.0 scipy-1.13.0 setuptools-68.2.2 six-1.16.0 sympy-1.12 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tifffile-2024.2.12 timm-0.9.16 torch-2.2.1 torchaudio-2.2.1 torchvision-0.17.1 tqdm-4.66.2 triton-2.2.0 typing-extensions-4.11.0 urllib3-2.2.1 werkzeug-3.0.2 wheel-0.41.2 yacs-0.1.8
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate conda_PatREID
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.2.2
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.2.2%2Bcu118-cp310-cp310-linux_x86_64.whl (819.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.2/819.2 MB 42.5 MB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.17.2
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.17.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 35.8 MB/s eta 0:00:00
# Collecting torchaudio==2.2.2
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.2.2%2Bcu118-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 50.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (4.13.2)
# Requirement already satisfied: sympy in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (1.14.0)
# Requirement already satisfied: networkx in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torch==2.2.2) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 42.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 28.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 43.3 MB/s eta 0:00:0000:01
# Collecting nvidia-cudnn-cu11==8.7.0.84 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-8.7.0.84-py3-none-manylinux1_x86_64.whl (728.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 48.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 28.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 57.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 61.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 56.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 62.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu11==2.19.3 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.19.3-py3-none-manylinux1_x86_64.whl (135.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 54.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.2.0 (from torch==2.2.2)
#   Downloading https://download.pytorch.org/whl/triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 60.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torchvision==0.17.2) (2.2.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from torchvision==0.17.2) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from jinja2->torch==2.2.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages (from sympy->torch==2.2.2) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.3.0
#     Uninstalling triton-3.3.0:
#       Successfully uninstalled triton-3.3.0
#   Attempting uninstall: torch━━━━━━━━╺━━━━━━━━━━ 11/15 [nvidia-cudnn-cu11]11]1]1]
#     Found existing installation: torch 2.7.0━━━━━━━━━━ 11/15 [nvidia-cudnn-cu11]
#     Uninstalling torch-2.7.0:━━━━━━━━━━━╺━━━━━━━ 12/15 [torch]nn-cu11]
#       Successfully uninstalled torch-2.7.00m╺━━━━━━━ 12/15 [torch]
#   Attempting uninstall: torchvision━━━━━╺━━━━━━━ 12/15 [torch]
#     Found existing installation: torchvision 0.22.0━━━━━━━ 12/15 [torch]
#     Uninstalling torchvision-0.22.0:━━━━━━╸━━━━━ 13/15 [torchvision]
#       Successfully uninstalled torchvision-0.22.0━━━━━ 13/15 [torchvision]
#   Attempting uninstall: torchaudio━━━━━━━━╸━━━━━ 13/15 [torchvision]
#     Found existing installation: torchaudio 2.7.0━━━━━ 13/15 [torchvision]
#     Uninstalling torchaudio-2.7.0:━━━━╸━━━━━ 13/15 [torchvision]
#       Successfully uninstalled torchaudio-2.7.0╸━━━━━ 13/15 [torchvision]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [torchaudio]5 [torchaudio]
# Successfully installed nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-8.7.0.84 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.19.3 nvidia-nvtx-cu11-11.8.86 torch-2.2.2+cu118 torchaudio-2.2.2+cu118 torchvision-0.17.2+cu118 triton-2.2.0

# %%
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 59.0 MB/s eta 0:00:00:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# Successfully installed numpy-1.26.4

# %% [markdown]
# ## Download base models
#
# For PAT: You can download it from huggingface, rwightman, or else where. For example, pretrained model is avaliable at https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-vitjx/jx_vit_base_p16_224-80ecf9dd.pth.

# %%
# !pip install wget
# !python -m wget https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-vitjx/jx_vit_base_p16_224-80ecf9dd.pth -o ../jx_vit_base_p16_224-80ecf9dd.pth
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   DEPRECATION: Building 'wget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wget'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9687 sha256=cb8b8eca7c36b3630a811b4c86da141832d675501b114024dac8894cea8b4b46
#   Stored in directory: /home/alumnos/e536103/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# 100% [..................................................] 346292833 / 346292833
# Saved under ../jx_vit_base_p16_224-80ecf9dd.pth
