# %%
# !python ../../Part-Aware-Transformer/train.py --config_file "UAM_containers.yml"
# Out:
# 2025-05-07 11:59:58,978 PAT INFO: Saving model in the path :/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Logs/UAM
# 2025-05-07 11:59:58,978 PAT INFO: Namespace(config_file='UAM_containers.yml', opts=[], local_rank=0)
# 2025-05-07 11:59:58,978 PAT INFO: Loaded configuration file UAM_containers.yml
# 2025-05-07 11:59:58,978 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #test
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
# ...

# %%
# !python ../../Part-Aware-Transformer/update.py --config_file "UAM_containers_test.yml" --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track.txt"
# Out:
# 2025-05-07 12:17:33,157 PAT INFO: Namespace(config_file='UAM_containers_test.yml', opts=[], track='/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track.txt')
# 2025-05-07 12:17:33,158 PAT INFO: Loaded configuration file UAM_containers_test.yml
# 2025-05-07 12:17:33,158 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
#     PROB: 0.5
# ...

# %%
# !python ../../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track.txt" --path="../../../ICIP_UrbAM-ReID/splits/Containers/containers/"
# Out:
# mAP= 0.70186674645821
# CMC-1 =0.76732673267327
# CMC-5 =0.89603960396040
# CMC-10 =0.94554455445545
# CMC-15 =0.95544554455446
# CMC-20 =0.96039603960396
# CMC-30 =0.99009900990099
# CMC-45 =0.99504950495050
# CMC-100 =0.99504950495050
