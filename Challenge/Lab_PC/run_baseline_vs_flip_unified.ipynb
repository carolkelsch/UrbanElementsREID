# %%
# !python ../../Part-Aware-Transformer/train.py --config_file "UAM_unified.yml"
# Out:
# 2025-05-09 17:47:24,188 PAT INFO: Saving model in the path :/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Logs/UAM
# 2025-05-09 17:47:24,188 PAT INFO: Namespace(config_file='UAM_unified.yml', opts=[], local_rank=0)
# 2025-05-09 17:47:24,189 PAT INFO: Loaded configuration file UAM_unified.yml
# 2025-05-09 17:47:24,189 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #test
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
# ...

# %%
# !python ../../Part-Aware-Transformer/update.py --config_file "UAM_unified_test.yml" --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_unified.txt"
# Out:
# 2025-05-09 18:27:53,630 PAT INFO: Namespace(config_file='UAM_unified_test.yml', opts=[], track='/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_unified.txt')
# 2025-05-09 18:27:53,630 PAT INFO: Loaded configuration file UAM_unified_test.yml
# 2025-05-09 18:27:53,630 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
# ...

# %% [markdown]
# ## Run with flip
# track file should be renamed to no erase baseline

# %%
# !python ../../Part-Aware-Transformer/update_flip.py --config_file "UAM_unified_test.yml" --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_flip_unified.txt"
# Out:
# 2025-05-09 18:28:37,943 PAT INFO: Namespace(config_file='UAM_unified_test.yml', opts=[], track='/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_flip_unified.txt')
# 2025-05-09 18:28:37,943 PAT INFO: Loaded configuration file UAM_unified_test.yml
# 2025-05-09 18:28:37,943 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
# ...

# %% [markdown]
# ## Compare outputs
# 1st normal updated vs. 2nd inference with flipped too

# %%
# !python ../../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_unified.txt" --path="/media/DiscoLocal/IPCV/Carolina/unified_dataset/unified/"
# Out:
# mAP= 0.41365997581297
# CMC-1 =0.41708542713568
# CMC-5 =0.63316582914573
# CMC-10 =0.76884422110553
# CMC-15 =0.83919597989950
# CMC-20 =0.87437185929648
# CMC-30 =0.89447236180905
# CMC-45 =0.94472361809045
# CMC-100 =0.98994974874372

# %%
# !python ../../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/Results/track_flip_unified.txt" --path="/media/DiscoLocal/IPCV/Carolina/unified_dataset/unified/"
# Out:
# mAP= 0.43200005955266
# CMC-1 =0.38693467336683
# CMC-5 =0.65829145728643
# CMC-10 =0.78391959798995
# CMC-15 =0.83919597989950
# CMC-20 =0.88944723618090
# CMC-30 =0.90954773869347
# CMC-45 =0.95979899497487
# CMC-100 =1.00000000000000
