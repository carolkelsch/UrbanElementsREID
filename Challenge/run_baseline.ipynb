# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/IPCV-DLI/LAB3/UrbanElementsREID/Part-Aware-Transformer

# %%
# !bash ../UrbAM-ReID/environmentPAT.yml
# Out:
# ../UrbAM-ReID/environmentPAT.yml: line 1: name:: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 2: $'channels:\r': command not found
# ../UrbAM-ReID/environmentPAT.yml: line 3: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 4: $'dependencies:\r': command not found
# ../UrbAM-ReID/environmentPAT.yml: line 5: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 6: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 7: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 8: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 9: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 10: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 11: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 12: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 13: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 14: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 15: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 16: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 17: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 18: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 19: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 20: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 21: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 22: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 23: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 24: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 25: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 26: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 27: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 28: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 29: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 30: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 31: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 32: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 33: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 34: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 35: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 36: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 37: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 38: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 39: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 40: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 41: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 42: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 43: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 44: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 45: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 46: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 47: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 48: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 49: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 50: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 51: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 52: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 53: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 54: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 55: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 56: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 57: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 58: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 59: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 60: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 61: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 62: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 63: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 64: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 65: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 66: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 67: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 68: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 69: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 70: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 71: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 72: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 73: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 74: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 75: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 76: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 77: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 78: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 79: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 80: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 81: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 82: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 83: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 84: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 85: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 86: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 87: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 88: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 89: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 90: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 91: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 92: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 93: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 94: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 95: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 96: -: command not found
# ../UrbAM-ReID/environmentPAT.yml: line 97: $'prefix:\r': command not found
# ../UrbAM-ReID/environmentPAT.yml: line 98: $'\r': command not found

# %%
# !python ../Part-Aware-Transformer/train.py --config_file "../Part-Aware-Transformer/config/UAM_containers.yml"
# Out:
# 2025-05-04 11:19:17.886964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746357557.917999   12950 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746357557.927634   12950 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 11:19:17.956870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/IPCV-DLI/LAB3/UrbanElementsREID/Part-Aware-Transformer/../Part-Aware-Transformer/train.py", line 38, in <module>
#     cfg.merge_from_file(args.config_file)
#   File "/usr/local/lib/python3.11/dist-packages/yacs/config.py", line 211, in merge_from_file
#     with open(cfg_filename, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../Part-Aware-Transformer/config/UAM_containers.yml'

# %%
# !python ../Part-Aware-Transformer/update.py --config_file "../Part-Aware-Transformer/config/UAM_containers_test.yml" --track="Results/track.txt"
# Out:
# 2025-04-08 12:02:15,095 PAT INFO: Namespace(config_file='../Part-Aware-Transformer/config/UAM_containers_test.yml', opts=[], track='Results/track.txt')
# 2025-04-08 12:02:15,096 PAT INFO: Loaded configuration file ../Part-Aware-Transformer/config/UAM_containers_test.yml
# 2025-04-08 12:02:15,096 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
#     PROB: 0.5
#
# DATASETS:
#   TRAIN: ('UAM',)
#   TEST: ('UAM_test',)
#   #ROOT_DIR: ('../../data') # root of datasets
#   ROOT_DIR: '/media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/'
#
# DATALOADER:
#   SAMPLER: 'softmax_triplet'
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#
# SOLVER:
#   OPTIMIZER_NAME: 'SGD'
#   MAX_EPOCHS: 60
#   BASE_LR: 0.001 # 0.0004 for msmt
#   IMS_PER_BATCH: 64
#   WARMUP_METHOD: 'linear'
#   LARGE_FC_LR: False
#   CHECKPOINT_PERIOD: 5
#   LOG_PERIOD: 60
#   EVAL_PERIOD: 1
#   WEIGHT_DECAY:  1e-4
#   WEIGHT_DECAY_BIAS: 1e-4
#   BIAS_LR_FACTOR: 2
#   SEED: 1234
#
# TEST:
#   EVAL: True
#   IMS_PER_BATCH: 128
#   RE_RANKING: False
#   WEIGHT: "/media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth" #test
#   NECK_FEAT: 'before'
#   FEAT_NORM: True
#
# LOG_ROOT: '../../data/' # root of log file
# TB_LOG_ROOT: './tb_log/'
# LOG_NAME: '../UAM'
#
# 2025-04-08 12:02:15,096 PAT INFO: Running with config:
# DATALOADER:
#   CAMERA_TO_DOMAIN: False
#   DELETE_REM: False
#   DROP_LAST: False
#   INDIVIDUAL: False
#   NAIVE_WAY: True
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#   SAMPLER: softmax_triplet
# DATASETS:
#   COMBINEALL: False
#   ROOT_DIR: /media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/
#   TEST: ('UAM_test',)
#   TRAIN: ('UAM',)
# INPUT:
#   CJ:
#     BRIGHTNESS: 0.15
#     CONTRAST: 0.15
#     ENABLED: False
#     HUE: 0.1
#     PROB: 1.0
#     SATURATION: 0.1
#   DO_AUGMIX: False
#   DO_AUTOAUG: False
#   DO_FLIP: True
#   DO_PAD: True
#   FLIP_PROB: 0.5
#   LGT:
#     DO_LGT: True
#     PROB: 0.5
#   PADDING: 10
#   PADDING_MODE: constant
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   REA:
#     ENABLED: False
#     MEAN: [123.675, 116.28, 103.53]
#     PROB: 0.5
#   RPT:
#     ENABLED: False
#     PROB: 0.5
#   SIZE_TEST: [256, 128]
#   SIZE_TRAIN: [256, 128]
# LOG_NAME: ../UAM
# LOG_ROOT: ../../data/
# MODEL:
#   ATT_DROP_RATE: 0.0
#   CLUSTER_K: 10
#   COS_LAYER: False
#   DEVICE: cuda
#   DEVICE_ID: 0
#   DIST_TRAIN: False
#   DROP_OUT: 0.0
#   DROP_PATH: 0.1
#   FREEZE_PATCH_EMBED: True
#   ID_LOSS_TYPE: softmax
#   ID_LOSS_WEIGHT: 1.0
#   IF_LABELSMOOTH: on
#   IF_WITH_CENTER: no
#   LAST_STRIDE: 1
#   METRIC_LOSS_TYPE: triplet
#   NAME: part_attention_vit
#   NECK: bnneck
#   NO_MARGIN: True
#   PATCH_EMBED_TYPE:
#   PC_LOSS: True
#   PC_LR: 1.0
#   PC_SCALE: 0.02
#   PRETRAIN_CHOICE: imagenet
#   PRETRAIN_PATH: /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/
#   SOFT_LABEL: True
#   SOFT_LAMBDA: 0.5
#   SOFT_WEIGHT: 0.5
#   STRIDE_SIZE: [16, 16]
#   TRANSFORMER_TYPE: vit_base_patch16_224_TransReID
#   TRIPLET_LOSS_WEIGHT: 1.0
# SOLVER:
#   BASE_LR: 0.001
#   BIAS_LR_FACTOR: 2
#   CENTER_LOSS_WEIGHT: 0.0005
#   CENTER_LR: 0.5
#   CHECKPOINT_PERIOD: 5
#   COSINE_MARGIN: 0.5
#   COSINE_SCALE: 30
#   EVAL_PERIOD: 1
#   GAMMA: 0.1
#   IMS_PER_BATCH: 64
#   LARGE_FC_LR: False
#   LOG_PERIOD: 60
#   MARGIN: 0.3
#   MAX_EPOCHS: 60
#   MOMENTUM: 0.9
#   OPTIMIZER_NAME: SGD
#   SEED: 1234
#   STEPS: (40, 70)
#   WARMUP_EPOCHS: 5
#   WARMUP_FACTOR: 0.01
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.0001
#   WEIGHT_DECAY_BIAS: 0.0001
# TB_LOG_ROOT: ./tb_log/
# TEST:
#   DIST_MAT: dist_mat.npy
#   EVAL: True
#   FEAT_NORM: True
#   IMS_PER_BATCH: 128
#   NECK_FEAT: before
#   RE_RANKING: False
#   WEIGHT: /media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth
# using Transformer_type: part token vit as a backbone
# using stride: [16, 16], and patch number is num_y16 * num_x8
# using drop_out rate is : 0.0
# using attn_drop_out rate is : 0.0
# using drop_path rate is : 0.1
# Resized position embedding from size:torch.Size([1, 197, 768]) to size: torch.Size([1, 132, 768]) with height:16 width: 8
# Load 153 / 155 layers.
# Loading pretrained ImageNet model......from /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/jx_vit_base_p16_224-80ecf9dd.pth
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# ===========building our part attention vit===========
# 2025-04-08 12:02:16,283 PAT.train INFO: Number of parameter: 86.52M
# Loading trained model from /media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth
# 2025-04-08 12:02:17,047 PAT INFO: => Loaded UAM_test
# 2025-04-08 12:02:17,047 PAT INFO:   ----------------------------------------
# 2025-04-08 12:02:17,047 PAT INFO:   subset   | # ids | # images | # cameras
# 2025-04-08 12:02:17,047 PAT INFO:   ----------------------------------------
# 2025-04-08 12:02:17,047 PAT INFO:   query    |     1 |      202 |         1
# 2025-04-08 12:02:17,047 PAT INFO:   gallery  |     1 |      424 |         2
# 2025-04-08 12:02:17,047 PAT INFO:   ----------------------------------------
# 2025-04-08 12:02:17,048 PAT.test INFO: Enter inferencing
# 2025-04-08 12:02:19,498 PAT.test INFO: Validation Results
# 2025-04-08 12:02:19,498 PAT.test INFO: mAP: 100.0%
# 2025-04-08 12:02:19,498 PAT.test INFO: CMC curve, Rank-1  :100.0%
# 2025-04-08 12:02:19,498 PAT.test INFO: CMC curve, Rank-5  :100.0%
# 2025-04-08 12:02:19,498 PAT.test INFO: CMC curve, Rank-10 :100.0%
# 2025-04-08 12:02:19,499 PAT.test INFO: total inference time: 2.35
# m: 202  n: 100
# [348  26  72 314 275  39  50 324 394 226 208 211 107  38  68 338 189 334
#  227 290 235 200 198 381  33  81 194 415  54  59 197  98 260 121 132  31
#  321 403 309 357 151 282 364  15  19 221  77 141 336 355  11 295 259  28
#  170 246 192 201 258 187 298  52 303 419 284 422   2 366   0 349 174 176
#  365  94 232 173  46 392 205  56 236 101 233 320 148 242  36 139  29 380
#  122 118 126 114 190 399  43  18  17 325]
# (202, 100)

# %%
# !python ../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="Results/track.txt" --path="../../ICIP_UrbAM-ReID/splits/Containers/containers/"
# Out:
# mAP= 0.70269396128619
# CMC-1 =0.79207920792079
# CMC-5 =0.90594059405941
# CMC-10 =0.94059405940594
# CMC-15 =0.95544554455446
# CMC-20 =0.98019801980198
# CMC-30 =0.99504950495050
# CMC-45 =0.99504950495050
# CMC-100 =0.99504950495050
