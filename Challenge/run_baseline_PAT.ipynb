# %%
# !bash ../UrbAM-ReID/environmentPAT.yml
# Out:
# ../UrbAM-ReID/environmentPAT.yml: línea 1: name:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 2: channels:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 3: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 4: dependencies:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 5: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 6: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 7: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 8: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 9: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 10: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 11: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 12: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 13: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 14: -: orden no encontrada
# ...

# %%
# !python ../Part-Aware-Transformer/train.py --config_file "../Part-Aware-Transformer/config/UAM_containers.yml"
# Out:
# 2025-04-08 11:51:43,334 PAT INFO: Saving model in the path :../../data/../UAM
# 2025-04-08 11:51:43,335 PAT INFO: Namespace(config_file='../Part-Aware-Transformer/config/UAM_containers.yml', opts=[], local_rank=0)
# 2025-04-08 11:51:43,335 PAT INFO: Loaded configuration file ../Part-Aware-Transformer/config/UAM_containers.yml
# 2025-04-08 11:51:43,335 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #test
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
# ...

# %%
# !python ../Part-Aware-Transformer/update.py --config_file "../Part-Aware-Transformer/config/UAM_containers_test.yml" --track="Results/track.txt"
# Out:
# 2025-04-08 12:02:15,095 PAT INFO: Namespace(config_file='../Part-Aware-Transformer/config/UAM_containers_test.yml', opts=[], track='Results/track.txt')
# 2025-04-08 12:02:15,096 PAT INFO: Loaded configuration file ../Part-Aware-Transformer/config/UAM_containers_test.yml
# 2025-04-08 12:02:15,096 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
# ...

# %%
# !python ../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="Results/track.txt" --path="../../ICIP_UrbAM-ReID/splits/Containers/containers/"
# Out:
# mAP= 0.70269396128619
# CMC-1 =0.79207920792079
# CMC-5 =0.90594059405941
# CMC-10 =0.94059405940594
# CMC-15 =0.95544554455446
# CMC-20 =0.98019801980198
# CMC-30 =0.99504950495050
# CMC-45 =0.99504950495050
# CMC-100 =0.99504950495050
