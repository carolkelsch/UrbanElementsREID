# %%
# !bash ../UrbAM-ReID/environmentPAT.yml
# Out:
# ../UrbAM-ReID/environmentPAT.yml: línea 1: name:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 2: channels:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 3: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 4: dependencies:: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 5: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 6: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 7: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 8: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 9: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 10: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 11: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 12: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 13: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 14: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 15: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 16: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 17: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 18: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 19: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 20: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 21: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 22: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 23: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 24: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 25: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 26: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 27: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 28: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 29: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 30: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 31: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 32: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 33: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 34: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 35: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 36: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 37: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 38: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 39: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 40: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 41: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 42: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 43: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 44: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 45: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 46: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 47: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 48: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 49: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 50: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 51: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 52: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 53: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 54: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 55: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 56: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 57: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 58: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 59: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 60: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 61: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 62: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 63: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 64: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 65: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 66: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 67: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 68: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 69: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 70: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 71: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 72: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 73: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 74: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 75: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 76: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 77: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 78: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 79: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 80: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 81: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 82: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 83: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 84: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 85: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 86: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 87: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 88: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 89: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 90: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 91: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 92: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 93: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 94: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 95: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 96: -: orden no encontrada
# ../UrbAM-ReID/environmentPAT.yml: línea 97: prefix:: orden no encontrada

# %%
# !python ../Part-Aware-Transformer/train.py --config_file "../Part-Aware-Transformer/config/UAM_containers.yml"
# Out:
# 2025-04-30 12:37:11,711 PAT INFO: Saving model in the path :../../data/../UAM
# 2025-04-30 12:37:11,711 PAT INFO: Namespace(config_file='../Part-Aware-Transformer/config/UAM_containers.yml', opts=[], local_rank=0)
# 2025-04-30 12:37:11,712 PAT INFO: Loaded configuration file ../Part-Aware-Transformer/config/UAM_containers.yml
# 2025-04-30 12:37:11,712 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #test
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
#     PROB: 0.5
#
# DATASETS:
#   TRAIN: ('UAM',)
#   TEST: ('UAM',)
#   #ROOT_DIR: ('../../data') # root of datasets
#   ROOT_DIR: '/media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/'
#
# DATALOADER:
#   SAMPLER: 'softmax_triplet'
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#
# SOLVER:
#   OPTIMIZER_NAME: 'SGD'
#   MAX_EPOCHS: 60
#   BASE_LR: 0.001 # 0.0004 for msmt
#   IMS_PER_BATCH: 64
#   WARMUP_METHOD: 'linear'
#   LARGE_FC_LR: False
#   CHECKPOINT_PERIOD: 5
#   LOG_PERIOD: 60
#   EVAL_PERIOD: 1
#   WEIGHT_DECAY:  1e-4
#   WEIGHT_DECAY_BIAS: 1e-4
#   BIAS_LR_FACTOR: 2
#   SEED: 1234
#
# TEST:
#   EVAL: True
#   IMS_PER_BATCH: 128
#   RE_RANKING: False
#   WEIGHT: ''
#   NECK_FEAT: 'before'
#   FEAT_NORM: True
#
# LOG_ROOT: '../../data/' # root of log file
# TB_LOG_ROOT: './tb_log/'
# LOG_NAME: '../UAM'
#
# 2025-04-30 12:37:11,713 PAT INFO: Running with config:
# DATALOADER:
#   CAMERA_TO_DOMAIN: False
#   DELETE_REM: False
#   DROP_LAST: False
#   INDIVIDUAL: False
#   NAIVE_WAY: True
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#   SAMPLER: softmax_triplet
# DATASETS:
#   COMBINEALL: False
#   ROOT_DIR: /media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/
#   TEST: ('UAM',)
#   TRAIN: ('UAM',)
# INPUT:
#   CJ:
#     BRIGHTNESS: 0.15
#     CONTRAST: 0.15
#     ENABLED: False
#     HUE: 0.1
#     PROB: 1.0
#     SATURATION: 0.1
#   DO_AUGMIX: False
#   DO_AUTOAUG: False
#   DO_FLIP: True
#   DO_PAD: True
#   FLIP_PROB: 0.5
#   LGT:
#     DO_LGT: True
#     PROB: 0.5
#   PADDING: 10
#   PADDING_MODE: constant
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   REA:
#     ENABLED: False
#     MEAN: [123.675, 116.28, 103.53]
#     PROB: 0.5
#   RPT:
#     ENABLED: False
#     PROB: 0.5
#   SIZE_TEST: [256, 128]
#   SIZE_TRAIN: [256, 128]
# LOG_NAME: ../UAM
# LOG_ROOT: ../../data/
# MODEL:
#   ATT_DROP_RATE: 0.0
#   CLUSTER_K: 10
#   COS_LAYER: False
#   DEVICE: cuda
#   DEVICE_ID: 0
#   DIST_TRAIN: False
#   DROP_OUT: 0.0
#   DROP_PATH: 0.1
#   FREEZE_PATCH_EMBED: True
#   ID_LOSS_TYPE: softmax
#   ID_LOSS_WEIGHT: 1.0
#   IF_LABELSMOOTH: on
#   IF_WITH_CENTER: no
#   LAST_STRIDE: 1
#   METRIC_LOSS_TYPE: triplet
#   NAME: part_attention_vit
#   NECK: bnneck
#   NO_MARGIN: True
#   PATCH_EMBED_TYPE:
#   PC_LOSS: True
#   PC_LR: 1.0
#   PC_SCALE: 0.02
#   PRETRAIN_CHOICE: imagenet
#   PRETRAIN_PATH: /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/
#   SOFT_LABEL: True
#   SOFT_LAMBDA: 0.5
#   SOFT_WEIGHT: 0.5
#   STRIDE_SIZE: [16, 16]
#   TRANSFORMER_TYPE: vit_base_patch16_224_TransReID
#   TRIPLET_LOSS_WEIGHT: 1.0
# SOLVER:
#   BASE_LR: 0.001
#   BIAS_LR_FACTOR: 2
#   CENTER_LOSS_WEIGHT: 0.0005
#   CENTER_LR: 0.5
#   CHECKPOINT_PERIOD: 5
#   COSINE_MARGIN: 0.5
#   COSINE_SCALE: 30
#   EVAL_PERIOD: 1
#   GAMMA: 0.1
#   IMS_PER_BATCH: 64
#   LARGE_FC_LR: False
#   LOG_PERIOD: 60
#   MARGIN: 0.3
#   MAX_EPOCHS: 60
#   MOMENTUM: 0.9
#   OPTIMIZER_NAME: SGD
#   SEED: 1234
#   STEPS: (40, 70)
#   WARMUP_EPOCHS: 5
#   WARMUP_FACTOR: 0.01
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.0001
#   WEIGHT_DECAY_BIAS: 0.0001
# TB_LOG_ROOT: ./tb_log/
# TEST:
#   DIST_MAT: dist_mat.npy
#   EVAL: True
#   FEAT_NORM: True
#   IMS_PER_BATCH: 128
#   NECK_FEAT: before
#   RE_RANKING: False
#   WEIGHT:
# 2025-04-30 12:37:11,755 PAT INFO: => Loaded UAM
# 2025-04-30 12:37:11,755 PAT INFO:   ----------------------------------------
# 2025-04-30 12:37:11,755 PAT INFO:   subset   | # ids | # images | # cameras
# 2025-04-30 12:37:11,755 PAT INFO:   ----------------------------------------
# 2025-04-30 12:37:11,756 PAT INFO:   train    |    58 |      781 |         3
# 2025-04-30 12:37:11,756 PAT INFO:   ----------------------------------------
# 2025-04-30 12:37:11,771 PAT INFO: => Loaded UAM
# 2025-04-30 12:37:11,771 PAT INFO:   ----------------------------------------
# 2025-04-30 12:37:11,772 PAT INFO:   subset   | # ids | # images | # cameras
# 2025-04-30 12:37:11,772 PAT INFO:   ----------------------------------------
# 2025-04-30 12:37:11,772 PAT INFO:   query    |    58 |      781 |         3
# 2025-04-30 12:37:11,772 PAT INFO:   gallery  |    58 |      781 |         3
# 2025-04-30 12:37:11,772 PAT INFO:   ----------------------------------------
# using Transformer_type: part token vit as a backbone
# using stride: [16, 16], and patch number is num_y16 * num_x8
# using drop_out rate is : 0.0
# using attn_drop_out rate is : 0.0
# using drop_path rate is : 0.1
# Resized position embedding from size:torch.Size([1, 197, 768]) to size: torch.Size([1, 132, 768]) with height:16 width: 8
# Load 153 / 155 layers.
# Loading pretrained ImageNet model......from /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/jx_vit_base_p16_224-80ecf9dd.pth
# ===========building our part attention vit===========
# 2025-04-30 12:37:13,086 PAT.train INFO: Number of parameter: 86.57M
# ====== freeze patch_embed for stability ======
# using soft triplet loss for training
# label smooth on, numclasses: 58
# ========using soft label========
# 2025-04-30 12:37:13,498 PAT.train INFO: start training
# saving tblog to ./tb_log/../UAM
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Part-Aware-Transformer/processor/part_attention_vit_processor.py:52: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler(init_scale=512)
# initialize the centers
# initialization done
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Part-Aware-Transformer/processor/part_attention_vit_processor.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=True):
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Part-Aware-Transformer/loss/myloss.py:29: UserWarning: This overload of addmm_ is deprecated:
# 	addmm_(Number beta, Number alpha, Tensor mat1, Tensor mat2)
# Consider using one of the following signatures instead:
# 	addmm_(Tensor mat1, Tensor mat2, *, Number beta = 1, Number alpha = 1) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   dist_map.addmm_(1, -2, part_feat, part_centers.t())
# 2025-04-30 12:39:35,142 PAT.train INFO: Epoch 19 done. Time per batch: 0.291[s] Speed: 219.6[samples/s]
# 2025-04-30 12:39:35,142 PAT.test INFO: Enter inferencing
# 2025-04-30 12:39:40,175 PAT.test INFO: Validation Results
# 2025-04-30 12:39:40,175 PAT.test INFO: mAP: 49.3%
# 2025-04-30 12:39:40,175 PAT.test INFO: CMC curve, Rank-1  :51.0%
# 2025-04-30 12:39:40,175 PAT.test INFO: CMC curve, Rank-5  :83.2%
# 2025-04-30 12:39:40,175 PAT.test INFO: CMC curve, Rank-10 :93.5%
# 2025-04-30 12:39:40,175 PAT.test INFO: total inference time: 5.03
# 2025-04-30 12:39:42,774 PAT.train INFO: Epoch 20 done. Time per batch: 0.280[s] Speed: 228.7[samples/s]
# 2025-04-30 12:39:42,774 PAT.test INFO: Enter inferencing
# 2025-04-30 12:39:47,371 PAT.test INFO: Validation Results
# 2025-04-30 12:39:47,371 PAT.test INFO: mAP: 50.8%
# 2025-04-30 12:39:47,371 PAT.test INFO: CMC curve, Rank-1  :51.9%
# 2025-04-30 12:39:47,371 PAT.test INFO: CMC curve, Rank-5  :85.0%
# 2025-04-30 12:39:47,371 PAT.test INFO: CMC curve, Rank-10 :94.2%
# 2025-04-30 12:39:47,371 PAT.test INFO: total inference time: 4.59
# 2025-04-30 12:39:47,372 PAT.train INFO: =====best epoch: 20=====
# 2025-04-30 12:39:50,025 PAT.train INFO: Epoch 21 done. Time per batch: 0.255[s] Speed: 251.1[samples/s]
# 2025-04-30 12:39:50,025 PAT.test INFO: Enter inferencing
# 2025-04-30 12:39:54,584 PAT.test INFO: Validation Results
# 2025-04-30 12:39:54,585 PAT.test INFO: mAP: 52.8%
# 2025-04-30 12:39:54,585 PAT.test INFO: CMC curve, Rank-1  :53.6%
# 2025-04-30 12:39:54,585 PAT.test INFO: CMC curve, Rank-5  :86.2%
# 2025-04-30 12:39:54,585 PAT.test INFO: CMC curve, Rank-10 :94.2%
# 2025-04-30 12:39:54,585 PAT.test INFO: total inference time: 4.56
# 2025-04-30 12:39:56,760 PAT.train INFO: Epoch 22 done. Time per batch: 0.262[s] Speed: 244.4[samples/s]
# 2025-04-30 12:39:56,760 PAT.test INFO: Enter inferencing
# 2025-04-30 12:40:01,357 PAT.test INFO: Validation Results
# 2025-04-30 12:40:01,357 PAT.test INFO: mAP: 54.3%
# 2025-04-30 12:40:01,357 PAT.test INFO: CMC curve, Rank-1  :54.2%
# 2025-04-30 12:40:01,357 PAT.test INFO: CMC curve, Rank-5  :87.8%
# 2025-04-30 12:40:01,357 PAT.test INFO: CMC curve, Rank-10 :94.0%
# 2025-04-30 12:40:01,357 PAT.test INFO: total inference time: 4.59
# 2025-04-30 12:40:03,724 PAT.train INFO: Epoch 23 done. Time per batch: 0.254[s] Speed: 252.1[samples/s]
# 2025-04-30 12:40:03,725 PAT.test INFO: Enter inferencing
# 2025-04-30 12:40:08,283 PAT.test INFO: Validation Results
# 2025-04-30 12:40:08,283 PAT.test INFO: mAP: 55.3%
# 2025-04-30 12:40:38,237 PAT.train INFO: Epoch 28 done. Time per batch: 0.259[s] Speed: 247.5[samples/s]
# 2025-04-30 12:40:38,237 PAT.test INFO: Enter inferencing
# 2025-04-30 12:40:42,867 PAT.test INFO: Validation Results
# 2025-04-30 12:40:42,867 PAT.test INFO: mAP: 61.5%
# 2025-04-30 12:40:42,867 PAT.test INFO: CMC curve, Rank-1  :60.6%
# 2025-04-30 12:40:42,867 PAT.test INFO: CMC curve, Rank-5  :90.3%
# 2025-04-30 12:40:42,867 PAT.test INFO: CMC curve, Rank-10 :96.3%
# 2025-04-30 12:40:42,867 PAT.test INFO: total inference time: 4.63
# 2025-04-30 12:40:45,265 PAT.train INFO: Epoch 29 done. Time per batch: 0.257[s] Speed: 249.0[samples/s]
# 2025-04-30 12:40:45,265 PAT.test INFO: Enter inferencing
# 2025-04-30 12:40:49,863 PAT.test INFO: Validation Results
# 2025-04-30 12:40:49,863 PAT.test INFO: mAP: 62.7%
# 2025-04-30 12:40:49,863 PAT.test INFO: CMC curve, Rank-1  :62.1%
# 2025-04-30 12:40:49,863 PAT.test INFO: CMC curve, Rank-5  :89.8%
# 2025-04-30 12:40:49,863 PAT.test INFO: CMC curve, Rank-10 :96.7%
# 2025-04-30 12:40:49,863 PAT.test INFO: total inference time: 4.60
# 2025-04-30 12:40:52,226 PAT.train INFO: Epoch 30 done. Time per batch: 0.253[s] Speed: 252.7[samples/s]
# 2025-04-30 12:40:52,226 PAT.test INFO: Enter inferencing
# 2025-04-30 12:40:56,826 PAT.test INFO: Validation Results
# 2025-04-30 12:40:56,826 PAT.test INFO: mAP: 63.5%
# 2025-04-30 12:40:56,826 PAT.test INFO: CMC curve, Rank-1  :63.1%
# 2025-04-30 12:40:56,826 PAT.test INFO: CMC curve, Rank-5  :91.2%
# 2025-04-30 12:40:56,826 PAT.test INFO: CMC curve, Rank-10 :96.5%
# 2025-04-30 12:40:56,826 PAT.test INFO: total inference time: 4.60
# 2025-04-30 12:40:56,828 PAT.train INFO: =====best epoch: 30=====
# 2025-04-30 12:40:59,517 PAT.train INFO: Epoch 31 done. Time per batch: 0.258[s] Speed: 247.9[samples/s]
# 2025-04-30 12:40:59,517 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:04,260 PAT.test INFO: Validation Results
# 2025-04-30 12:41:04,260 PAT.test INFO: mAP: 65.1%
# 2025-04-30 12:41:04,260 PAT.test INFO: CMC curve, Rank-1  :64.0%
# 2025-04-30 12:41:04,260 PAT.test INFO: CMC curve, Rank-5  :91.4%
# 2025-04-30 12:41:04,260 PAT.test INFO: CMC curve, Rank-10 :97.1%
# 2025-04-30 12:41:04,260 PAT.test INFO: total inference time: 4.74
# 2025-04-30 12:41:06,685 PAT.train INFO: Epoch 32 done. Time per batch: 0.260[s] Speed: 246.2[samples/s]
# 2025-04-30 12:41:06,685 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:11,280 PAT.test INFO: Validation Results
# 2025-04-30 12:41:11,280 PAT.test INFO: mAP: 66.2%
# 2025-04-30 12:41:11,280 PAT.test INFO: CMC curve, Rank-1  :65.4%
# 2025-04-30 12:41:11,280 PAT.test INFO: CMC curve, Rank-5  :91.5%
# 2025-04-30 12:41:11,280 PAT.test INFO: CMC curve, Rank-10 :96.9%
# 2025-04-30 12:41:11,280 PAT.test INFO: total inference time: 4.59
# 2025-04-30 12:41:13,443 PAT.train INFO: Epoch 33 done. Time per batch: 0.260[s] Speed: 246.1[samples/s]
# 2025-04-30 12:41:13,443 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:18,021 PAT.test INFO: Validation Results
# 2025-04-30 12:41:18,021 PAT.test INFO: mAP: 67.3%
# 2025-04-30 12:41:18,021 PAT.test INFO: CMC curve, Rank-1  :65.4%
# 2025-04-30 12:41:18,021 PAT.test INFO: CMC curve, Rank-5  :92.8%
# 2025-04-30 12:41:18,021 PAT.test INFO: CMC curve, Rank-10 :97.4%
# 2025-04-30 12:41:18,021 PAT.test INFO: total inference time: 4.57
# 2025-04-30 12:41:20,161 PAT.train INFO: Epoch 34 done. Time per batch: 0.257[s] Speed: 249.0[samples/s]
# 2025-04-30 12:41:20,161 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:24,758 PAT.test INFO: Validation Results
# 2025-04-30 12:41:24,758 PAT.test INFO: mAP: 67.7%
# 2025-04-30 12:41:24,758 PAT.test INFO: CMC curve, Rank-1  :65.4%
# 2025-04-30 12:41:24,758 PAT.test INFO: CMC curve, Rank-5  :92.4%
# 2025-04-30 12:41:24,758 PAT.test INFO: CMC curve, Rank-10 :97.2%
# 2025-04-30 12:41:24,758 PAT.test INFO: total inference time: 4.59
# 2025-04-30 12:41:27,138 PAT.train INFO: Epoch 35 done. Time per batch: 0.255[s] Speed: 250.8[samples/s]
# 2025-04-30 12:41:27,138 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:31,736 PAT.test INFO: Validation Results
# 2025-04-30 12:41:31,736 PAT.test INFO: mAP: 68.8%
# 2025-04-30 12:41:31,736 PAT.test INFO: CMC curve, Rank-1  :66.7%
# 2025-04-30 12:41:31,736 PAT.test INFO: CMC curve, Rank-5  :93.6%
# 2025-04-30 12:41:31,736 PAT.test INFO: CMC curve, Rank-10 :97.6%
# 2025-04-30 12:41:31,736 PAT.test INFO: total inference time: 4.60
# 2025-04-30 12:41:31,737 PAT.train INFO: =====best epoch: 35=====
# 2025-04-30 12:41:34,375 PAT.train INFO: Epoch 36 done. Time per batch: 0.254[s] Speed: 251.6[samples/s]
# 2025-04-30 12:41:34,375 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:38,989 PAT.test INFO: Validation Results
# 2025-04-30 12:41:38,989 PAT.test INFO: mAP: 69.7%
# 2025-04-30 12:41:38,989 PAT.test INFO: CMC curve, Rank-1  :67.2%
# 2025-04-30 12:41:38,989 PAT.test INFO: CMC curve, Rank-5  :93.3%
# 2025-04-30 12:41:38,989 PAT.test INFO: CMC curve, Rank-10 :98.0%
# 2025-04-30 12:41:38,989 PAT.test INFO: total inference time: 4.61
# 2025-04-30 12:41:41,369 PAT.train INFO: Epoch 37 done. Time per batch: 0.255[s] Speed: 250.7[samples/s]
# 2025-04-30 12:41:41,369 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:45,965 PAT.test INFO: Validation Results
# 2025-04-30 12:41:45,965 PAT.test INFO: mAP: 70.5%
# 2025-04-30 12:41:45,965 PAT.test INFO: CMC curve, Rank-1  :68.2%
# 2025-04-30 12:41:45,965 PAT.test INFO: CMC curve, Rank-5  :93.9%
# 2025-04-30 12:41:45,965 PAT.test INFO: CMC curve, Rank-10 :97.7%
# 2025-04-30 12:41:45,965 PAT.test INFO: total inference time: 4.59
# 2025-04-30 12:41:48,339 PAT.train INFO: Epoch 38 done. Time per batch: 0.254[s] Speed: 251.5[samples/s]
# 2025-04-30 12:41:48,339 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:52,939 PAT.test INFO: Validation Results
# 2025-04-30 12:41:52,939 PAT.test INFO: mAP: 71.3%
# 2025-04-30 12:41:52,939 PAT.test INFO: CMC curve, Rank-1  :69.0%
# 2025-04-30 12:41:52,939 PAT.test INFO: CMC curve, Rank-5  :94.1%
# 2025-04-30 12:41:52,939 PAT.test INFO: CMC curve, Rank-10 :97.7%
# 2025-04-30 12:41:52,939 PAT.test INFO: total inference time: 4.60
# 2025-04-30 12:41:55,101 PAT.train INFO: Epoch 39 done. Time per batch: 0.260[s] Speed: 246.1[samples/s]
# 2025-04-30 12:41:55,102 PAT.test INFO: Enter inferencing
# 2025-04-30 12:41:59,838 PAT.test INFO: Validation Results
# 2025-04-30 12:41:59,838 PAT.test INFO: mAP: 72.4%
# 2025-04-30 12:41:59,839 PAT.test INFO: CMC curve, Rank-1  :69.8%
# 2025-04-30 12:41:59,839 PAT.test INFO: CMC curve, Rank-5  :94.1%
# 2025-04-30 12:41:59,839 PAT.test INFO: CMC curve, Rank-10 :98.0%
# 2025-04-30 12:41:59,839 PAT.test INFO: total inference time: 4.73
# 2025-04-30 12:42:02,256 PAT.train INFO: Epoch 40 done. Time per batch: 0.259[s] Speed: 246.7[samples/s]
# 2025-04-30 12:42:02,257 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:06,867 PAT.test INFO: Validation Results
# 2025-04-30 12:42:06,867 PAT.test INFO: mAP: 73.8%
# 2025-04-30 12:42:06,867 PAT.test INFO: CMC curve, Rank-1  :71.1%
# 2025-04-30 12:42:06,867 PAT.test INFO: CMC curve, Rank-5  :94.8%
# 2025-04-30 12:42:06,867 PAT.test INFO: CMC curve, Rank-10 :97.8%
# 2025-04-30 12:42:06,867 PAT.test INFO: total inference time: 4.61
# 2025-04-30 12:42:06,868 PAT.train INFO: =====best epoch: 40=====
# 2025-04-30 12:42:09,515 PAT.train INFO: Epoch 41 done. Time per batch: 0.255[s] Speed: 251.2[samples/s]
# 2025-04-30 12:42:09,515 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:14,167 PAT.test INFO: Validation Results
# 2025-04-30 12:42:14,167 PAT.test INFO: mAP: 74.9%
# 2025-04-30 12:42:14,168 PAT.test INFO: CMC curve, Rank-1  :72.0%
# 2025-04-30 12:42:14,168 PAT.test INFO: CMC curve, Rank-5  :95.3%
# 2025-04-30 12:42:14,168 PAT.test INFO: CMC curve, Rank-10 :98.6%
# 2025-04-30 12:42:14,168 PAT.test INFO: total inference time: 4.65
# 2025-04-30 12:42:16,365 PAT.train INFO: Epoch 42 done. Time per batch: 0.264[s] Speed: 242.2[samples/s]
# 2025-04-30 12:42:16,365 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:20,971 PAT.test INFO: Validation Results
# 2025-04-30 12:42:20,971 PAT.test INFO: mAP: 75.3%
# 2025-04-30 12:42:20,971 PAT.test INFO: CMC curve, Rank-1  :72.1%
# 2025-04-30 12:42:20,971 PAT.test INFO: CMC curve, Rank-5  :95.3%
# 2025-04-30 12:42:20,971 PAT.test INFO: CMC curve, Rank-10 :98.5%
# 2025-04-30 12:42:20,971 PAT.test INFO: total inference time: 4.60
# 2025-04-30 12:42:23,376 PAT.train INFO: Epoch 43 done. Time per batch: 0.258[s] Speed: 248.3[samples/s]
# 2025-04-30 12:42:23,376 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:28,343 PAT.test INFO: Validation Results
# 2025-04-30 12:42:28,343 PAT.test INFO: mAP: 76.1%
# 2025-04-30 12:42:28,343 PAT.test INFO: CMC curve, Rank-1  :73.9%
# 2025-04-30 12:42:28,343 PAT.test INFO: CMC curve, Rank-5  :95.5%
# 2025-04-30 12:42:28,343 PAT.test INFO: CMC curve, Rank-10 :98.6%
# 2025-04-30 12:42:28,343 PAT.test INFO: total inference time: 4.96
# 2025-04-30 12:42:30,908 PAT.train INFO: Epoch 44 done. Time per batch: 0.276[s] Speed: 232.0[samples/s]
# 2025-04-30 12:42:30,908 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:35,810 PAT.test INFO: Validation Results
# 2025-04-30 12:42:35,810 PAT.test INFO: mAP: 76.5%
# 2025-04-30 12:42:35,810 PAT.test INFO: CMC curve, Rank-1  :73.6%
# 2025-04-30 12:42:35,810 PAT.test INFO: CMC curve, Rank-5  :95.3%
# 2025-04-30 12:42:35,811 PAT.test INFO: CMC curve, Rank-10 :98.8%
# 2025-04-30 12:42:35,811 PAT.test INFO: total inference time: 4.90
# 2025-04-30 12:42:38,186 PAT.train INFO: Epoch 45 done. Time per batch: 0.255[s] Speed: 251.1[samples/s]
# 2025-04-30 12:42:38,187 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:42,842 PAT.test INFO: Validation Results
# 2025-04-30 12:42:42,842 PAT.test INFO: mAP: 77.2%
# 2025-04-30 12:42:42,842 PAT.test INFO: CMC curve, Rank-1  :75.2%
# 2025-04-30 12:42:42,842 PAT.test INFO: CMC curve, Rank-5  :95.8%
# 2025-04-30 12:42:42,842 PAT.test INFO: CMC curve, Rank-10 :98.8%
# 2025-04-30 12:42:42,842 PAT.test INFO: total inference time: 4.65
# 2025-04-30 12:42:42,843 PAT.train INFO: =====best epoch: 45=====
# 2025-04-30 12:42:45,751 PAT.train INFO: Epoch 46 done. Time per batch: 0.274[s] Speed: 233.8[samples/s]
# 2025-04-30 12:42:45,752 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:50,376 PAT.test INFO: Validation Results
# 2025-04-30 12:42:50,376 PAT.test INFO: mAP: 77.8%
# 2025-04-30 12:42:50,376 PAT.test INFO: CMC curve, Rank-1  :75.8%
# 2025-04-30 12:42:50,376 PAT.test INFO: CMC curve, Rank-5  :96.4%
# 2025-04-30 12:42:50,376 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:42:50,376 PAT.test INFO: total inference time: 4.62
# 2025-04-30 12:42:52,865 PAT.train INFO: Epoch 47 done. Time per batch: 0.267[s] Speed: 239.3[samples/s]
# 2025-04-30 12:42:52,865 PAT.test INFO: Enter inferencing
# 2025-04-30 12:42:57,871 PAT.test INFO: Validation Results
# 2025-04-30 12:42:57,871 PAT.test INFO: mAP: 78.6%
# 2025-04-30 12:42:57,871 PAT.test INFO: CMC curve, Rank-1  :77.0%
# 2025-04-30 12:42:57,871 PAT.test INFO: CMC curve, Rank-5  :96.3%
# 2025-04-30 12:42:57,871 PAT.test INFO: CMC curve, Rank-10 :98.7%
# 2025-04-30 12:42:57,871 PAT.test INFO: total inference time: 5.00
# 2025-04-30 12:43:00,358 PAT.train INFO: Epoch 48 done. Time per batch: 0.267[s] Speed: 239.7[samples/s]
# 2025-04-30 12:43:00,359 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:04,975 PAT.test INFO: Validation Results
# 2025-04-30 12:43:04,975 PAT.test INFO: mAP: 79.2%
# 2025-04-30 12:43:04,975 PAT.test INFO: CMC curve, Rank-1  :77.7%
# 2025-04-30 12:43:04,975 PAT.test INFO: CMC curve, Rank-5  :96.3%
# 2025-04-30 12:43:04,975 PAT.test INFO: CMC curve, Rank-10 :98.7%
# 2025-04-30 12:43:04,975 PAT.test INFO: total inference time: 4.61
# 2025-04-30 12:43:07,186 PAT.train INFO: Epoch 49 done. Time per batch: 0.266[s] Speed: 240.7[samples/s]
# 2025-04-30 12:43:07,187 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:11,852 PAT.test INFO: Validation Results
# 2025-04-30 12:43:11,852 PAT.test INFO: mAP: 79.6%
# 2025-04-30 12:43:11,852 PAT.test INFO: CMC curve, Rank-1  :77.6%
# 2025-04-30 12:43:11,852 PAT.test INFO: CMC curve, Rank-5  :96.3%
# 2025-04-30 12:43:11,852 PAT.test INFO: CMC curve, Rank-10 :98.7%
# 2025-04-30 12:43:11,852 PAT.test INFO: total inference time: 4.66
# 2025-04-30 12:43:14,264 PAT.train INFO: Epoch 50 done. Time per batch: 0.259[s] Speed: 247.5[samples/s]
# 2025-04-30 12:43:14,265 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:18,961 PAT.test INFO: Validation Results
# 2025-04-30 12:43:18,961 PAT.test INFO: mAP: 80.3%
# 2025-04-30 12:43:18,961 PAT.test INFO: CMC curve, Rank-1  :78.4%
# 2025-04-30 12:43:18,961 PAT.test INFO: CMC curve, Rank-5  :96.5%
# 2025-04-30 12:43:18,961 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:43:18,961 PAT.test INFO: total inference time: 4.69
# 2025-04-30 12:43:18,962 PAT.train INFO: =====best epoch: 50=====
# 2025-04-30 12:43:21,782 PAT.train INFO: Epoch 51 done. Time per batch: 0.273[s] Speed: 234.1[samples/s]
# 2025-04-30 12:43:21,782 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:26,648 PAT.test INFO: Validation Results
# 2025-04-30 12:43:26,648 PAT.test INFO: mAP: 80.9%
# 2025-04-30 12:43:26,648 PAT.test INFO: CMC curve, Rank-1  :79.6%
# 2025-04-30 12:43:26,648 PAT.test INFO: CMC curve, Rank-5  :96.8%
# 2025-04-30 12:43:26,648 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:43:26,648 PAT.test INFO: total inference time: 4.86
# 2025-04-30 12:43:29,062 PAT.train INFO: Epoch 52 done. Time per batch: 0.259[s] Speed: 246.8[samples/s]
# 2025-04-30 12:43:29,063 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:33,789 PAT.test INFO: Validation Results
# 2025-04-30 12:43:33,789 PAT.test INFO: mAP: 81.3%
# 2025-04-30 12:43:33,789 PAT.test INFO: CMC curve, Rank-1  :79.8%
# 2025-04-30 12:43:33,789 PAT.test INFO: CMC curve, Rank-5  :96.7%
# 2025-04-30 12:43:33,789 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:43:33,789 PAT.test INFO: total inference time: 4.72
# 2025-04-30 12:43:36,382 PAT.train INFO: Epoch 53 done. Time per batch: 0.279[s] Speed: 229.6[samples/s]
# 2025-04-30 12:43:36,382 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:41,004 PAT.test INFO: Validation Results
# 2025-04-30 12:43:41,004 PAT.test INFO: mAP: 81.4%
# 2025-04-30 12:43:41,004 PAT.test INFO: CMC curve, Rank-1  :79.4%
# 2025-04-30 12:43:41,004 PAT.test INFO: CMC curve, Rank-5  :96.4%
# 2025-04-30 12:43:41,004 PAT.test INFO: CMC curve, Rank-10 :99.1%
# 2025-04-30 12:43:41,004 PAT.test INFO: total inference time: 4.62
# 2025-04-30 12:43:43,410 PAT.train INFO: Epoch 54 done. Time per batch: 0.258[s] Speed: 248.1[samples/s]
# 2025-04-30 12:43:43,411 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:48,138 PAT.test INFO: Validation Results
# 2025-04-30 12:43:48,139 PAT.test INFO: mAP: 81.6%
# 2025-04-30 12:43:48,139 PAT.test INFO: CMC curve, Rank-1  :79.1%
# 2025-04-30 12:43:48,139 PAT.test INFO: CMC curve, Rank-5  :96.0%
# 2025-04-30 12:43:48,139 PAT.test INFO: CMC curve, Rank-10 :98.8%
# 2025-04-30 12:43:48,139 PAT.test INFO: total inference time: 4.72
# 2025-04-30 12:43:50,912 PAT.train INFO: Epoch 55 done. Time per batch: 0.299[s] Speed: 214.1[samples/s]
# 2025-04-30 12:43:50,913 PAT.test INFO: Enter inferencing
# 2025-04-30 12:43:55,656 PAT.test INFO: Validation Results
# 2025-04-30 12:43:55,656 PAT.test INFO: mAP: 82.1%
# 2025-04-30 12:43:55,656 PAT.test INFO: CMC curve, Rank-1  :80.3%
# 2025-04-30 12:43:55,656 PAT.test INFO: CMC curve, Rank-5  :96.8%
# 2025-04-30 12:43:55,656 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:43:55,656 PAT.test INFO: total inference time: 4.74
# 2025-04-30 12:43:55,658 PAT.train INFO: =====best epoch: 55=====
# 2025-04-30 12:43:58,394 PAT.train INFO: Epoch 56 done. Time per batch: 0.261[s] Speed: 245.6[samples/s]
# 2025-04-30 12:43:58,394 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:03,035 PAT.test INFO: Validation Results
# 2025-04-30 12:44:03,035 PAT.test INFO: mAP: 82.5%
# 2025-04-30 12:44:03,035 PAT.test INFO: CMC curve, Rank-1  :80.5%
# 2025-04-30 12:44:03,035 PAT.test INFO: CMC curve, Rank-5  :96.7%
# 2025-04-30 12:44:03,035 PAT.test INFO: CMC curve, Rank-10 :99.1%
# 2025-04-30 12:44:03,035 PAT.test INFO: total inference time: 4.64
# 2025-04-30 12:44:05,180 PAT.train INFO: Epoch 57 done. Time per batch: 0.258[s] Speed: 248.3[samples/s]
# 2025-04-30 12:44:05,180 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:09,829 PAT.test INFO: Validation Results
# 2025-04-30 12:44:09,829 PAT.test INFO: mAP: 82.8%
# 2025-04-30 12:44:09,829 PAT.test INFO: CMC curve, Rank-1  :80.9%
# 2025-04-30 12:44:09,829 PAT.test INFO: CMC curve, Rank-5  :96.8%
# 2025-04-30 12:44:09,829 PAT.test INFO: CMC curve, Rank-10 :99.1%
# 2025-04-30 12:44:09,829 PAT.test INFO: total inference time: 4.65
# 2025-04-30 12:44:11,983 PAT.train INFO: Epoch 58 done. Time per batch: 0.259[s] Speed: 247.5[samples/s]
# 2025-04-30 12:44:11,983 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:16,601 PAT.test INFO: Validation Results
# 2025-04-30 12:44:16,602 PAT.test INFO: mAP: 83.5%
# 2025-04-30 12:44:16,602 PAT.test INFO: CMC curve, Rank-1  :81.9%
# 2025-04-30 12:44:16,602 PAT.test INFO: CMC curve, Rank-5  :96.9%
# 2025-04-30 12:44:16,602 PAT.test INFO: CMC curve, Rank-10 :99.1%
# 2025-04-30 12:44:16,602 PAT.test INFO: total inference time: 4.62
# 2025-04-30 12:44:18,763 PAT.train INFO: Epoch 59 done. Time per batch: 0.260[s] Speed: 246.1[samples/s]
# 2025-04-30 12:44:18,764 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:23,386 PAT.test INFO: Validation Results
# 2025-04-30 12:44:23,386 PAT.test INFO: mAP: 84.1%
# 2025-04-30 12:44:23,386 PAT.test INFO: CMC curve, Rank-1  :82.2%
# 2025-04-30 12:44:23,386 PAT.test INFO: CMC curve, Rank-5  :97.1%
# 2025-04-30 12:44:23,386 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:44:23,386 PAT.test INFO: total inference time: 4.62
# 2025-04-30 12:44:25,764 PAT.train INFO: Epoch 60 done. Time per batch: 0.255[s] Speed: 250.9[samples/s]
# 2025-04-30 12:44:25,764 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:30,411 PAT.test INFO: Validation Results
# 2025-04-30 12:44:30,411 PAT.test INFO: mAP: 84.6%
# 2025-04-30 12:44:30,411 PAT.test INFO: CMC curve, Rank-1  :82.8%
# 2025-04-30 12:44:30,411 PAT.test INFO: CMC curve, Rank-5  :97.3%
# 2025-04-30 12:44:30,411 PAT.test INFO: CMC curve, Rank-10 :99.0%
# 2025-04-30 12:44:30,411 PAT.test INFO: total inference time: 4.64
# 2025-04-30 12:44:30,412 PAT.train INFO: =====best epoch: 60=====
# using Transformer_type: part token vit as a backbone
# using stride: [16, 16], and patch number is num_y16 * num_x8
# using drop_out rate is : 0.0
# using attn_drop_out rate is : 0.0
# using drop_path rate is : 0.1
# Resized position embedding from size:torch.Size([1, 197, 768]) to size: torch.Size([1, 132, 768]) with height:16 width: 8
# Load 153 / 155 layers.
# Loading pretrained ImageNet model......from /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/jx_vit_base_p16_224-80ecf9dd.pth
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# ===========building our part attention vit===========
# 2025-04-30 12:44:33,451 PAT.train INFO: Number of parameter: 86.52M
# Loading trained model from ../../data/../UAM/part_attention_vit_60.pth
# load weights from part_attention_vit_60.pth
# 2025-04-30 12:44:33,737 PAT INFO: => Loaded UAM
# 2025-04-30 12:44:33,737 PAT INFO:   ----------------------------------------
# 2025-04-30 12:44:33,737 PAT INFO:   subset   | # ids | # images | # cameras
# 2025-04-30 12:44:33,738 PAT INFO:   ----------------------------------------
# 2025-04-30 12:44:33,738 PAT INFO:   query    |    58 |      781 |         3
# 2025-04-30 12:44:33,738 PAT INFO:   gallery  |    58 |      781 |         3
# 2025-04-30 12:44:33,738 PAT INFO:   ----------------------------------------
# 2025-04-30 12:44:33,738 PAT.test INFO: Enter inferencing
# 2025-04-30 12:44:38,521 PAT.test INFO: Validation Results
# 2025-04-30 12:44:38,521 PAT.test INFO: mAP: 84.4%
# 2025-04-30 12:44:38,521 PAT.test INFO: CMC curve, Rank-1  :82.2%
# 2025-04-30 12:44:38,521 PAT.test INFO: CMC curve, Rank-5  :97.8%
# 2025-04-30 12:44:38,521 PAT.test INFO: CMC curve, Rank-10 :99.4%
# 2025-04-30 12:44:38,521 PAT.test INFO: total inference time: 4.72
# removing ../../data/../UAM/part_attention_vit_15.pth.
# removing ../../data/../UAM/part_attention_vit_60.pth.
# removing ../../data/../UAM/part_attention_vit_30.pth.
# removing ../../data/../UAM/part_attention_vit_40.pth.
# removing ../../data/../UAM/part_attention_vit_50.pth.
# removing ../../data/../UAM/part_attention_vit_55.pth.
# removing ../../data/../UAM/part_attention_vit_35.pth.
# removing ../../data/../UAM/part_attention_vit_5.pth.
# removing ../../data/../UAM/part_attention_vit_45.pth.
# removing ../../data/../UAM/part_attention_vit_20.pth.
# removing ../../data/../UAM/part_attention_vit_25.pth.
# removing ../../data/../UAM/part_attention_vit_10.pth.
# saving final checkpoint.
# Do not interrupt the program!!!
# done!

# %%
# !python ../Part-Aware-Transformer/update.py --config_file "../Part-Aware-Transformer/config/UAM_containers_test_inv.yml" --track="Results/track_inv.txt"
# Out:
# 2025-04-30 12:52:23,573 PAT INFO: Namespace(config_file='../Part-Aware-Transformer/config/UAM_containers_test_inv.yml', opts=[], track='Results/track_inv.txt')
# 2025-04-30 12:52:23,573 PAT INFO: Loaded configuration file ../Part-Aware-Transformer/config/UAM_containers_test_inv.yml
# 2025-04-30 12:52:23,574 PAT INFO:
# MODEL:
#   PRETRAIN_CHOICE: 'imagenet'
#   #PRETRAIN_PATH: "../../.cache/torch/hub/checkpoints" # root of pretrain path
#   #PRETRAIN_PATH: "./" #
#   PRETRAIN_PATH: "/media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/"
#   METRIC_LOSS_TYPE: 'triplet'
#   IF_LABELSMOOTH: 'on'
#   IF_WITH_CENTER: 'no'
#   NAME: 'part_attention_vit'
#   NO_MARGIN: True
#   DEVICE_ID: ('0')
#   TRANSFORMER_TYPE: 'vit_base_patch16_224_TransReID'
#   STRIDE_SIZE: [16, 16]
#
# INPUT:
#   SIZE_TRAIN: [256,128]
#   SIZE_TEST: [256,128]
#   REA:
#     ENABLED: False
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   LGT: # Local Grayscale Transfomation
#     DO_LGT: True
#     PROB: 0.5
#
# DATASETS:
#   TRAIN: ('UAM',)
#   TEST: ('UAM_test',)
#   #ROOT_DIR: ('../../data') # root of datasets
#   ROOT_DIR: '/media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/inv/'
#
# DATALOADER:
#   SAMPLER: 'softmax_triplet'
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#
# SOLVER:
#   OPTIMIZER_NAME: 'SGD'
#   MAX_EPOCHS: 60
#   BASE_LR: 0.001 # 0.0004 for msmt
#   IMS_PER_BATCH: 64
#   WARMUP_METHOD: 'linear'
#   LARGE_FC_LR: False
#   CHECKPOINT_PERIOD: 5
#   LOG_PERIOD: 60
#   EVAL_PERIOD: 1
#   WEIGHT_DECAY:  1e-4
#   WEIGHT_DECAY_BIAS: 1e-4
#   BIAS_LR_FACTOR: 2
#   SEED: 1234
#
# TEST:
#   EVAL: True
#   IMS_PER_BATCH: 128
#   RE_RANKING: False
#   #WEIGHT: "./logs/UAM/UAM_containers/part_attention_vit_60.pth"
#   WEIGHT: "/media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth"
#   NECK_FEAT: 'before'
#   FEAT_NORM: True
#
# LOG_ROOT: '../../data/' # root of log file
# TB_LOG_ROOT: './tb_log/'
# LOG_NAME: '../UAM'
#
# 2025-04-30 12:52:23,574 PAT INFO: Running with config:
# DATALOADER:
#   CAMERA_TO_DOMAIN: False
#   DELETE_REM: False
#   DROP_LAST: False
#   INDIVIDUAL: False
#   NAIVE_WAY: True
#   NUM_INSTANCE: 4
#   NUM_WORKERS: 8
#   SAMPLER: softmax_triplet
# DATASETS:
#   COMBINEALL: False
#   ROOT_DIR: /media/DiscoLocal/IPCV/Carolina/ICIP_UrbAM-ReID/splits/Containers/containers/inv/
#   TEST: ('UAM_test',)
#   TRAIN: ('UAM',)
# INPUT:
#   CJ:
#     BRIGHTNESS: 0.15
#     CONTRAST: 0.15
#     ENABLED: False
#     HUE: 0.1
#     PROB: 1.0
#     SATURATION: 0.1
#   DO_AUGMIX: False
#   DO_AUTOAUG: False
#   DO_FLIP: True
#   DO_PAD: True
#   FLIP_PROB: 0.5
#   LGT:
#     DO_LGT: True
#     PROB: 0.5
#   PADDING: 10
#   PADDING_MODE: constant
#   PIXEL_MEAN: [0.5, 0.5, 0.5]
#   PIXEL_STD: [0.5, 0.5, 0.5]
#   REA:
#     ENABLED: False
#     MEAN: [123.675, 116.28, 103.53]
#     PROB: 0.5
#   RPT:
#     ENABLED: False
#     PROB: 0.5
#   SIZE_TEST: [256, 128]
#   SIZE_TRAIN: [256, 128]
# LOG_NAME: ../UAM
# LOG_ROOT: ../../data/
# MODEL:
#   ATT_DROP_RATE: 0.0
#   CLUSTER_K: 10
#   COS_LAYER: False
#   DEVICE: cuda
#   DEVICE_ID: 0
#   DIST_TRAIN: False
#   DROP_OUT: 0.0
#   DROP_PATH: 0.1
#   FREEZE_PATCH_EMBED: True
#   ID_LOSS_TYPE: softmax
#   ID_LOSS_WEIGHT: 1.0
#   IF_LABELSMOOTH: on
#   IF_WITH_CENTER: no
#   LAST_STRIDE: 1
#   METRIC_LOSS_TYPE: triplet
#   NAME: part_attention_vit
#   NECK: bnneck
#   NO_MARGIN: True
#   PATCH_EMBED_TYPE:
#   PC_LOSS: True
#   PC_LR: 1.0
#   PC_SCALE: 0.02
#   PRETRAIN_CHOICE: imagenet
#   PRETRAIN_PATH: /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/
#   SOFT_LABEL: True
#   SOFT_LAMBDA: 0.5
#   SOFT_WEIGHT: 0.5
#   STRIDE_SIZE: [16, 16]
#   TRANSFORMER_TYPE: vit_base_patch16_224_TransReID
#   TRIPLET_LOSS_WEIGHT: 1.0
# SOLVER:
#   BASE_LR: 0.001
#   BIAS_LR_FACTOR: 2
#   CENTER_LOSS_WEIGHT: 0.0005
#   CENTER_LR: 0.5
#   CHECKPOINT_PERIOD: 5
#   COSINE_MARGIN: 0.5
#   COSINE_SCALE: 30
#   EVAL_PERIOD: 1
#   GAMMA: 0.1
#   IMS_PER_BATCH: 64
#   LARGE_FC_LR: False
#   LOG_PERIOD: 60
#   MARGIN: 0.3
#   MAX_EPOCHS: 60
#   MOMENTUM: 0.9
#   OPTIMIZER_NAME: SGD
#   SEED: 1234
#   STEPS: (40, 70)
#   WARMUP_EPOCHS: 5
#   WARMUP_FACTOR: 0.01
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.0001
#   WEIGHT_DECAY_BIAS: 0.0001
# TB_LOG_ROOT: ./tb_log/
# TEST:
#   DIST_MAT: dist_mat.npy
#   EVAL: True
#   FEAT_NORM: True
#   IMS_PER_BATCH: 128
#   NECK_FEAT: before
#   RE_RANKING: False
#   WEIGHT: /media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth
# using Transformer_type: part token vit as a backbone
# using stride: [16, 16], and patch number is num_y16 * num_x8
# using drop_out rate is : 0.0
# using attn_drop_out rate is : 0.0
# using drop_path rate is : 0.1
# Resized position embedding from size:torch.Size([1, 197, 768]) to size: torch.Size([1, 132, 768]) with height:16 width: 8
# Load 153 / 155 layers.
# Loading pretrained ImageNet model......from /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/Challenge/jx_vit_base_p16_224-80ecf9dd.pth
# /media/DiscoLocal/IPCV/Carolina/UrbanElementsREID/.conda/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# ===========building our part attention vit===========
# 2025-04-30 12:52:24,734 PAT.train INFO: Number of parameter: 86.52M
# Loading trained model from /media/DiscoLocal/IPCV/Carolina/UAM/part_attention_vit_60.pth
# 2025-04-30 12:52:25,479 PAT INFO: => Loaded UAM_test
# 2025-04-30 12:52:25,479 PAT INFO:   ----------------------------------------
# 2025-04-30 12:52:25,479 PAT INFO:   subset   | # ids | # images | # cameras
# 2025-04-30 12:52:25,479 PAT INFO:   ----------------------------------------
# 2025-04-30 12:52:25,479 PAT INFO:   query    |     1 |      155 |         1
# 2025-04-30 12:52:25,479 PAT INFO:   gallery  |     1 |      626 |         3
# 2025-04-30 12:52:25,479 PAT INFO:   ----------------------------------------
# 2025-04-30 12:52:25,479 PAT.test INFO: Enter inferencing
# 2025-04-30 12:52:28,354 PAT.test INFO: Validation Results
# 2025-04-30 12:52:28,354 PAT.test INFO: mAP: 100.0%
# 2025-04-30 12:52:28,354 PAT.test INFO: CMC curve, Rank-1  :100.0%
# 2025-04-30 12:52:28,354 PAT.test INFO: CMC curve, Rank-5  :100.0%
# 2025-04-30 12:52:28,354 PAT.test INFO: CMC curve, Rank-10 :100.0%
# 2025-04-30 12:52:28,354 PAT.test INFO: total inference time: 2.78
# m: 155  n: 100
# [321 198 596 450 467 531 355 419  12 599 443 167 130 412 369 251  54 561
#  422 551 593 415 293 152  13 383 176 345 336 506 202 232 342 382 149 211
#  179 438 559  62 144 468 529 381 583  40 306  85 327 323 312 219 516 278
#   33 324 482 246 420 224 234 240  75 106 349 343 388 478 437 210 243  98
#  137 166 255 153 227 400 201 197 616 257 233 389 435 380 377  34  83 404
#  205 319  22 286 317 594  37  64  21 557]
# (155, 100)

# %%
# !python ../UrbAM-ReID/Code/Evaluate_UrbAM-ReID.py --track="Results/track_inv.txt" --path="../../ICIP_UrbAM-ReID/splits/Containers/containers/inv"
# Out:
# mAP= 0.33615251922489
# CMC-1 =0.42580645161290
# CMC-5 =0.60000000000000
# CMC-10 =0.66451612903226
# CMC-15 =0.72903225806452
# CMC-20 =0.74193548387097
# CMC-30 =0.83870967741935
# CMC-45 =0.89032258064516
# CMC-100 =0.98709677419355
